# %%
# !kaggle competitions download -c challenges-in-representation-learning-facial-expression-recognition-challenge
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# Downloading train.csv.zip to /content
#  85% 66.0M/77.3M [00:00<00:00, 59.7MB/s]
# 100% 77.3M/77.3M [00:00<00:00, 93.1MB/s]
# Downloading test.csv.zip to /content
#  47% 9.00M/19.3M [00:00<00:00, 39.7MB/s]
# 100% 19.3M/19.3M [00:00<00:00, 64.5MB/s]
# Downloading fer2013.tar.gz to /content
#  91% 84.0M/92.0M [00:00<00:00, 90.7MB/s]
# 100% 92.0M/92.0M [00:00<00:00, 109MB/s]
# Downloading example_submission.csv to /content
#   0% 0.00/7.01k [00:00<?, ?B/s]
# 100% 7.01k/7.01k [00:00<00:00, 7.40MB/s]
# Downloading icml_face_data.csv.zip to /content
#  94% 91.0M/96.6M [00:01<00:00, 57.7MB/s]
# 100% 96.6M/96.6M [00:01<00:00, 82.6MB/s]

# %%
# !tar -xf /content/fer2013.tar.gz

# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import numpy as np
import csv
from PIL import Image
from torchvision.transforms import ToTensor
from torch.utils.data import DataLoader
from torch.utils.mobile_optimizer import optimize_for_mobile

device = torch.device('cuda')
shape = (44, 44)

# %%
class SeparableConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=1, stride=1, padding=0, dilation=1, bias=False):
        super(SeparableConv2d, self).__init__()
        self.depthwise = nn.Conv2d(in_channels, in_channels, kernel_size, stride, padding, dilation, groups=in_channels, bias=bias)
        self.pointwise = nn.Conv2d(in_channels, out_channels, 1, 1, 0, 1, 1, bias=bias)

    def forward(self, x):
        x = self.depthwise(x)
        x = self.pointwise(x)
        return x

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_channeld, out_channels):
        super(ResidualBlock, self).__init__()
        self.residual_conv = nn.Conv2d(in_channels=in_channeld, out_channels=out_channels, kernel_size=1, stride=2, bias=False)
        self.residual_bn = nn.BatchNorm2d(out_channels, momentum=0.99, eps=1e-3)
        self.sepConv1 = SeparableConv2d(in_channels=in_channeld, out_channels=out_channels, kernel_size=3, bias=False, padding=1)
        self.bn1 = nn.BatchNorm2d(out_channels, momentum=0.99, eps=1e-3)
        self.relu = nn.ReLU()
        self.sepConv2 = SeparableConv2d(in_channels=out_channels, out_channels=out_channels, kernel_size=3, bias=False, padding=1)
        self.bn2 = nn.BatchNorm2d(out_channels, momentum=0.99, eps=1e-3)
        self.maxp = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)

    def forward(self, x):
        res = self.residual_conv(x)
        res = self.residual_bn(res)
        x = self.sepConv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.sepConv2(x)
        x = self.bn2(x)
        x = self.maxp(x)
        return res + x

# %%
class Model(nn.Module):
    def __init__(self, num_classes):
        super(Model, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=8, kernel_size=3, stride=1, bias=False)
        self.bn1 = nn.BatchNorm2d(8, affine=True, momentum=0.99, eps=1e-3)
        self.relu1 = nn.ReLU()
        self.conv2 = nn.Conv2d(in_channels=8, out_channels=8, kernel_size=3, stride=1, bias=False)
        self.bn2 = nn.BatchNorm2d(8, momentum=0.99, eps=1e-3)
        self.relu2 = nn.ReLU()
        self.module1 = ResidualBlock(in_channeld=8, out_channels=16)
        self.module2 = ResidualBlock(in_channeld=16, out_channels=32)
        self.module3 = ResidualBlock(in_channeld=32, out_channels=64)
        self.module4 = ResidualBlock(in_channeld=64, out_channels=128)
        self.last_conv = nn.Conv2d(in_channels=128, out_channels=num_classes, kernel_size=3, padding=1)
        self.avgp = nn.AdaptiveAvgPool2d((1, 1))

    def forward(self, input):
        x = input
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu1(x)
        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu2(x)
        x = self.module1(x)
        x = self.module2(x)
        x = self.module3(x)
        x = self.module4(x)
        x = self.last_conv(x)
        x = self.avgp(x)
        x = x.view((x.shape[0], -1))
        return x

# %%
class DataSet(torch.utils.data.Dataset):
    def __init__(self, transform=None, images=None, emotions=None):
        self.transform = transform
        self.images = images
        self.emotions = emotions

    def __getitem__(self, index):
        image = self.images[index]
        emotion = self.emotions[index]
        if self.transform is not None:
            image = self.transform(image)
        return image, emotion

    def __len__(self):
        return len(self.images)

class DataSetFactory:
    def __init__(self):
        images = []
        emotions = []
        validate_images = []
        validate_emotions = []
        with open('/content/fer2013/fer2013.csv', 'r') as csvin:
            data = csv.reader(csvin)
            next(data)
            for row in data:
                face = [int(pixel) for pixel in row[1].split()]
                face = np.asarray(face).reshape(48, 48)
                face = face.astype('uint8')
                if row[-1] == 'Training':
                    emotions.append(int(row[0]))
                    images.append(Image.fromarray(face))
                else:
                    validate_emotions.append(int(row[0]))
                    validate_images.append(Image.fromarray(face))
        train_transform = transforms.Compose([
            transforms.RandomCrop(shape[0]),
            transforms.RandomHorizontalFlip(),
            ToTensor(),
        ])
        val_transform = transforms.Compose([
            transforms.CenterCrop(shape[0]),
            ToTensor(),
        ])
        self.train = DataSet(transform=train_transform, images=images, emotions=emotions)
        self.validate = DataSet(transform=val_transform, images=validate_images, emotions=validate_emotions)

# %%
def save_model():
    traced = torch.jit.trace(network, torch.rand(1, 1, shape[0], shape[1]))
    optimize_for_mobile(traced)
    traced.save("model.pt")

# %%
batch_size = 128
lr = 0.01
epochs = 300
learning_rate_decay_start = 80
learning_rate_decay_every = 5
learning_rate_decay_rate = 0.9
classes = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']
network = Model(num_classes=len(classes)).to(device)
optimizer = torch.optim.SGD(network.parameters(), lr=lr, momentum=0.9, weight_decay=5e-3)
criterion = nn.CrossEntropyLoss()
factory = DataSetFactory()
train_loader = DataLoader(factory.train, batch_size=batch_size, shuffle=True, num_workers=1)
validate_loader = DataLoader(factory.validate, batch_size=batch_size, shuffle=True, num_workers=1)
min_validation_loss = 10000

# %%
for epoch in range(epochs):
    network.train()
    total = 0
    correct = 0
    total_train_loss = 0
    if epoch > learning_rate_decay_start and learning_rate_decay_start >= 0:
        frac = (epoch - learning_rate_decay_start) // learning_rate_decay_every
        decay_factor = learning_rate_decay_rate ** frac
        current_lr = lr * decay_factor
        for group in optimizer.param_groups:
            group['lr'] = current_lr
    else:
        current_lr = lr
    print(f'learning_rate={str(current_lr)}')
    for i, (x_train, y_train) in enumerate(train_loader):
        optimizer.zero_grad()
        x_train = x_train.to(device)
        y_train = y_train.to(device)
        y_predicted = network(x_train)
        loss = criterion(y_predicted, y_train)
        loss.backward()
        optimizer.step()
        _, predicted = torch.max(y_predicted.data, 1)
        total_train_loss += loss.data
        total += y_train.size(0)
        correct += predicted.eq(y_train.data).sum()
    accuracy = 100. * float(correct) / total
    print(f'epoch={epoch + 1} total_train_loss={total_train_loss / (i + 1)} accuracy={accuracy}')
    network.eval()
    with torch.no_grad():
        total = 0
        correct = 0
        total_validation_loss = 0
        for j, (x_val, y_val) in enumerate(validate_loader):
            x_val = x_val.to(device)
            y_val = y_val.to(device)
            y_val_predicted = network(x_val)
            val_loss = criterion(y_val_predicted, y_val)
            _, predicted = torch.max(y_val_predicted.data, 1)
            total_validation_loss += val_loss.data
            total += y_val.size(0)
            correct += predicted.eq(y_val.data).sum()
        accuracy = 100. * float(correct) / total
        if total_validation_loss <= min_validation_loss:
            if epoch >= 10:
                print('saving model...')
                network.to('cpu')
                save_model()
                network.to('cuda')
            min_validation_loss = total_validation_loss
        print(f'epoch={epoch + 1} total_validation_loss={total_validation_loss / (j + 1)} accuracy={accuracy}')
# Out:
# learning_rate=0.01
# epoch=1 total_train_loss=1.7412625551223755 accuracy=30.861402347695844
# epoch=1 total_validation_loss=1.6147561073303223 accuracy=37.55920869322931
# learning_rate=0.01
# epoch=2 total_train_loss=1.4860056638717651 accuracy=42.68347904838204
# epoch=2 total_validation_loss=1.3857476711273193 accuracy=46.851490665923656
# learning_rate=0.01
# epoch=3 total_train_loss=1.3754483461380005 accuracy=47.35448813960779
# epoch=3 total_validation_loss=1.384629726409912 accuracy=47.40874895514071
# learning_rate=0.01
# epoch=4 total_train_loss=1.295423150062561 accuracy=50.447594830889265
# epoch=4 total_validation_loss=1.2947362661361694 accuracy=50.57118974644748
# learning_rate=0.01
# epoch=5 total_train_loss=1.2493195533752441 accuracy=52.4469678498032
# epoch=5 total_validation_loss=1.225332260131836 accuracy=52.911674561159096
# learning_rate=0.01
# epoch=6 total_train_loss=1.2156296968460083 accuracy=53.73924553275976
# epoch=6 total_validation_loss=1.2243950366973877 accuracy=53.719699080523824
# learning_rate=0.01
# epoch=7 total_train_loss=1.1804728507995605 accuracy=55.32063116095998
# epoch=7 total_validation_loss=1.1864575147628784 accuracy=53.85901365282808
# learning_rate=0.01
# epoch=8 total_train_loss=1.1652828454971313 accuracy=55.75951792120938
# epoch=8 total_validation_loss=1.1823402643203735 accuracy=55.18250208971858
# learning_rate=0.01
# epoch=9 total_train_loss=1.1432567834854126 accuracy=56.85673482183287
# epoch=9 total_validation_loss=1.1968460083007812 accuracy=53.900808024519364
# learning_rate=0.01
# epoch=10 total_train_loss=1.1337093114852905 accuracy=57.07269497370163
# epoch=10 total_validation_loss=1.1682833433151245 accuracy=55.628308721092225
# learning_rate=0.01
# epoch=11 total_train_loss=1.124658465385437 accuracy=57.36180291894528
# saving model...
# epoch=11 total_validation_loss=1.1577972173690796 accuracy=55.68403455001393
# learning_rate=0.01
# epoch=12 total_train_loss=1.1152516603469849 accuracy=57.80765613570657
# saving model...
# epoch=12 total_validation_loss=1.136528730392456 accuracy=56.56171635553079
# learning_rate=0.01
# epoch=13 total_train_loss=1.1070420742034912 accuracy=58.36845588491414
# epoch=13 total_validation_loss=1.1392465829849243 accuracy=56.129841181387576
# learning_rate=0.01
# epoch=14 total_train_loss=1.1012049913406372 accuracy=58.326657145842766
# epoch=14 total_validation_loss=1.146747350692749 accuracy=56.58957926999164
# learning_rate=0.01
# epoch=15 total_train_loss=1.0970418453216553 accuracy=58.61924831934237
# saving model...
# epoch=15 total_validation_loss=1.0947909355163574 accuracy=57.982724993034275
# learning_rate=0.01
# epoch=16 total_train_loss=1.093347430229187 accuracy=58.80037618865164
# epoch=16 total_validation_loss=1.1134543418884277 accuracy=57.7319587628866
# learning_rate=0.01
# epoch=17 total_train_loss=1.0836186408996582 accuracy=59.148699014246404
# epoch=17 total_validation_loss=1.1114304065704346 accuracy=57.03538590136528
# learning_rate=0.01
# epoch=18 total_train_loss=1.075320839881897 accuracy=59.62241805705528
# saving model...
# epoch=18 total_validation_loss=1.0932416915893555 accuracy=58.386737252716635
# learning_rate=0.01
# epoch=19 total_train_loss=1.0764580965042114 accuracy=59.347243024835414
# epoch=19 total_validation_loss=1.1335183382034302 accuracy=56.78461967121761
# learning_rate=0.01
# epoch=20 total_train_loss=1.073948621749878 accuracy=59.28106168797241
# epoch=20 total_validation_loss=1.1665078401565552 accuracy=55.64224017832265
# learning_rate=0.01
# epoch=21 total_train_loss=1.0667778253555298 accuracy=59.60848514403149
# epoch=21 total_validation_loss=1.0948526859283447 accuracy=58.53998328225132
# learning_rate=0.01
# epoch=22 total_train_loss=1.0655920505523682 accuracy=59.827928524156185
# epoch=22 total_validation_loss=1.1738728284835815 accuracy=55.89300640847033
# learning_rate=0.01
# epoch=23 total_train_loss=1.06047785282135 accuracy=60.172768121495004
# saving model...
# epoch=23 total_validation_loss=1.0718412399291992 accuracy=58.88826971301198
# learning_rate=0.01
# epoch=24 total_train_loss=1.058224081993103 accuracy=59.963774426138144
# epoch=24 total_validation_loss=1.0830799341201782 accuracy=58.87433825578155
# learning_rate=0.01
# epoch=25 total_train_loss=1.0585006475448608 accuracy=60.02995576300115
# epoch=25 total_validation_loss=1.1586565971374512 accuracy=56.32488158261354
# learning_rate=0.01
# epoch=26 total_train_loss=1.0535942316055298 accuracy=60.30513079522101
# epoch=26 total_validation_loss=1.0822707414627075 accuracy=59.23655614377264
# learning_rate=0.01
# epoch=27 total_train_loss=1.0556739568710327 accuracy=60.16580166498311
# epoch=27 total_validation_loss=1.105158805847168 accuracy=57.634438562273616
# learning_rate=0.01
# epoch=28 total_train_loss=1.0544925928115845 accuracy=60.25984882789369
# epoch=28 total_validation_loss=1.0743255615234375 accuracy=59.19476177208136
# learning_rate=0.01
# epoch=29 total_train_loss=1.0478792190551758 accuracy=60.562889686161135
# epoch=29 total_validation_loss=1.0868899822235107 accuracy=58.790749512398996
# learning_rate=0.01
# epoch=30 total_train_loss=1.0519793033599854 accuracy=60.40266118638755
# epoch=30 total_validation_loss=1.0974351167678833 accuracy=58.19169685149067
# learning_rate=0.01
# epoch=31 total_train_loss=1.0437700748443604 accuracy=60.64300393604793
# epoch=31 total_validation_loss=1.0823487043380737 accuracy=58.74895514070772
# learning_rate=0.01
# epoch=32 total_train_loss=1.0437463521957397 accuracy=60.970427392107005
# saving model...
# epoch=32 total_validation_loss=1.0709681510925293 accuracy=59.9052660908331
# learning_rate=0.01
# epoch=33 total_train_loss=1.0400515794754028 accuracy=60.869413772684524
# epoch=33 total_validation_loss=1.1168140172958374 accuracy=57.300083588743384
# learning_rate=0.01
# epoch=34 total_train_loss=1.0426206588745117 accuracy=60.681319446863355
# epoch=34 total_validation_loss=1.0726380348205566 accuracy=59.93312900529396
# learning_rate=0.01
# epoch=35 total_train_loss=1.0372916460037231 accuracy=60.834581490125046
# saving model...
# epoch=35 total_validation_loss=1.0651805400848389 accuracy=59.250487601003066
# learning_rate=0.01
# epoch=36 total_train_loss=1.0355144739151 accuracy=61.134139120136545
# epoch=36 total_validation_loss=1.077073335647583 accuracy=59.62663694622457
# learning_rate=0.01
# epoch=37 total_train_loss=1.0347833633422852 accuracy=60.81019889233342
# epoch=37 total_validation_loss=1.0732102394104004 accuracy=58.74895514070772
# learning_rate=0.01
# epoch=38 total_train_loss=1.034441590309143 accuracy=61.11672297885681
# epoch=38 total_validation_loss=1.081728458404541 accuracy=59.069378657007526
# learning_rate=0.01
# epoch=39 total_train_loss=1.0290884971618652 accuracy=61.088857152809226
# epoch=39 total_validation_loss=1.1285734176635742 accuracy=57.80161604903873
# learning_rate=0.01
# epoch=40 total_train_loss=1.0327892303466797 accuracy=60.904246055244
# epoch=40 total_validation_loss=1.0653940439224243 accuracy=59.640568403455
# learning_rate=0.01
# epoch=41 total_train_loss=1.0296920537948608 accuracy=61.43021352189209
# epoch=41 total_validation_loss=1.081627607345581 accuracy=59.5848425745333
# learning_rate=0.01
# epoch=42 total_train_loss=1.0324697494506836 accuracy=61.231669511303075
# epoch=42 total_validation_loss=1.0996439456939697 accuracy=58.094176650877685
# learning_rate=0.01
# epoch=43 total_train_loss=1.0325266122817993 accuracy=61.10975652234491
# epoch=43 total_validation_loss=1.070638656616211 accuracy=59.069378657007526
# learning_rate=0.01
# epoch=44 total_train_loss=1.0296310186386108 accuracy=61.09930683757707
# epoch=44 total_validation_loss=1.0926659107208252 accuracy=58.163833937029814
# learning_rate=0.01
# epoch=45 total_train_loss=1.027416706085205 accuracy=61.19335400048765
# epoch=45 total_validation_loss=1.1061877012252808 accuracy=57.62050710504319
# learning_rate=0.01
# epoch=46 total_train_loss=1.032411813735962 accuracy=61.31526698944582
# saving model...
# epoch=46 total_validation_loss=1.0608643293380737 accuracy=59.654499860685426
# learning_rate=0.01
# epoch=47 total_train_loss=1.0306062698364258 accuracy=61.3431328154934
# epoch=47 total_validation_loss=1.0730679035186768 accuracy=60.22568960713291
# learning_rate=0.01
# epoch=48 total_train_loss=1.0269691944122314 accuracy=61.207286913511446
# epoch=48 total_validation_loss=1.0646247863769531 accuracy=59.57091111730287
# learning_rate=0.01
# epoch=49 total_train_loss=1.0252765417099 accuracy=61.15155526141628
# epoch=49 total_validation_loss=1.0704323053359985 accuracy=59.487322373920314
# learning_rate=0.01
# epoch=50 total_train_loss=1.0256937742233276 accuracy=61.21077014176739
# epoch=50 total_validation_loss=1.094372034072876 accuracy=59.12510448592923
# learning_rate=0.01
# epoch=51 total_train_loss=1.0256574153900146 accuracy=61.26650179386255
# saving model...
# epoch=51 total_validation_loss=1.0572316646575928 accuracy=60.25355252159376
# learning_rate=0.01
# epoch=52 total_train_loss=1.0228787660598755 accuracy=61.52774391305862
# epoch=52 total_validation_loss=1.1015586853027344 accuracy=58.69322931178601
# learning_rate=0.01
# epoch=53 total_train_loss=1.0219398736953735 accuracy=61.77853634748685
# epoch=53 total_validation_loss=1.0698730945587158 accuracy=60.01671774867651
# learning_rate=0.01
# epoch=54 total_train_loss=1.0250132083892822 accuracy=61.28043470688634
# epoch=54 total_validation_loss=1.0632117986679077 accuracy=59.87740317637225
# learning_rate=0.01
# epoch=55 total_train_loss=1.0192968845367432 accuracy=61.79595248876659
# epoch=55 total_validation_loss=1.0637717247009277 accuracy=60.61577040958484
# learning_rate=0.01
# epoch=56 total_train_loss=1.02289617061615 accuracy=61.29436761991013
# saving model...
# epoch=56 total_validation_loss=1.0357897281646729 accuracy=60.79687935358039
# learning_rate=0.01
# epoch=57 total_train_loss=1.0170623064041138 accuracy=61.785502803998746
# epoch=57 total_validation_loss=1.076528787612915 accuracy=59.41766508776818
# learning_rate=0.01
# epoch=58 total_train_loss=1.0213826894760132 accuracy=61.77853634748685
# epoch=58 total_validation_loss=1.075238585472107 accuracy=58.70716076901644
# learning_rate=0.01
# epoch=59 total_train_loss=1.0225409269332886 accuracy=61.65314013027274
# epoch=59 total_validation_loss=1.0537916421890259 accuracy=60.72722206742825
# learning_rate=0.01
# epoch=60 total_train_loss=1.0187078714370728 accuracy=61.75067052143927
# epoch=60 total_validation_loss=1.048439383506775 accuracy=60.88046809696294
# learning_rate=0.01
# epoch=61 total_train_loss=1.017815351486206 accuracy=61.5556097391062
# epoch=61 total_validation_loss=1.1003472805023193 accuracy=58.735023683477294
# learning_rate=0.01
# epoch=62 total_train_loss=1.0200879573822021 accuracy=61.684489184576265
# epoch=62 total_validation_loss=1.076552391052246 accuracy=59.0554471997771
# learning_rate=0.01
# epoch=63 total_train_loss=1.018664836883545 accuracy=61.50684454352294
# epoch=63 total_validation_loss=1.0830042362213135 accuracy=58.679297854555585
# learning_rate=0.01
# epoch=64 total_train_loss=1.015258550643921 accuracy=61.54516005433836
# epoch=64 total_validation_loss=1.0769122838974 accuracy=58.69322931178601
# learning_rate=0.01
# epoch=65 total_train_loss=1.0148649215698242 accuracy=61.52426068480268
# epoch=65 total_validation_loss=1.066924810409546 accuracy=59.320144887155195
# learning_rate=0.01
# epoch=66 total_train_loss=1.011574149131775 accuracy=61.86910028214149
# epoch=66 total_validation_loss=1.0717124938964844 accuracy=59.50125383115074
# learning_rate=0.01
# epoch=67 total_train_loss=1.0147830247879028 accuracy=61.68797241283221
# epoch=67 total_validation_loss=1.0817641019821167 accuracy=59.41766508776818
# learning_rate=0.01
# epoch=68 total_train_loss=1.0157064199447632 accuracy=61.52426068480268
# saving model...
# epoch=68 total_validation_loss=1.0331844091415405 accuracy=61.27054889941488
# learning_rate=0.01
# epoch=69 total_train_loss=1.0126421451568604 accuracy=62.046744923194815
# epoch=69 total_validation_loss=1.098496675491333 accuracy=58.916132627472834
# learning_rate=0.01
# epoch=70 total_train_loss=1.0147784948349 accuracy=61.639207217248945
# epoch=70 total_validation_loss=1.0717520713806152 accuracy=59.45945945945946
# learning_rate=0.01
# epoch=71 total_train_loss=1.016220211982727 accuracy=61.75067052143927
# epoch=71 total_validation_loss=1.0641396045684814 accuracy=60.28141543605461
# learning_rate=0.01
# epoch=72 total_train_loss=1.0127177238464355 accuracy=61.903932564700966
# epoch=72 total_validation_loss=1.0981175899505615 accuracy=58.971858456394536
# learning_rate=0.01
# epoch=73 total_train_loss=1.0111351013183594 accuracy=62.16169145564109
# epoch=73 total_validation_loss=1.1760179996490479 accuracy=56.380607411535244
# learning_rate=0.01
# epoch=74 total_train_loss=1.016011118888855 accuracy=61.55212651085026
# epoch=74 total_validation_loss=1.0752205848693848 accuracy=58.76288659793814
# learning_rate=0.01
# epoch=75 total_train_loss=1.0101540088653564 accuracy=61.87258351039743
# epoch=75 total_validation_loss=1.0630719661712646 accuracy=59.91919754806353
# learning_rate=0.01
# epoch=76 total_train_loss=1.0111887454986572 accuracy=61.88999965167717
# epoch=76 total_validation_loss=1.0803438425064087 accuracy=59.487322373920314
# learning_rate=0.01
# epoch=77 total_train_loss=1.0145248174667358 accuracy=61.785502803998746
# epoch=77 total_validation_loss=1.0441858768463135 accuracy=59.94706046252438
# learning_rate=0.01
# epoch=78 total_train_loss=1.005662441253662 accuracy=62.00842941237939
# epoch=78 total_validation_loss=1.0821706056594849 accuracy=59.5848425745333
# learning_rate=0.01
# epoch=79 total_train_loss=1.0099605321884155 accuracy=61.97011390156397
# epoch=79 total_validation_loss=1.0630940198898315 accuracy=60.239621064363334
# learning_rate=0.01
# epoch=80 total_train_loss=1.0163646936416626 accuracy=61.945731303772334
# epoch=80 total_validation_loss=1.0590811967849731 accuracy=59.45945945945946
# learning_rate=0.01
# epoch=81 total_train_loss=1.01076078414917 accuracy=61.92483193423665
# epoch=81 total_validation_loss=1.0407980680465698 accuracy=60.9083310114238
# learning_rate=0.01
# epoch=82 total_train_loss=1.0111010074615479 accuracy=62.00842941237939
# epoch=82 total_validation_loss=1.0504134893417358 accuracy=60.67149623850655
# learning_rate=0.01
# epoch=83 total_train_loss=1.008684515953064 accuracy=61.87258351039743
# epoch=83 total_validation_loss=1.0805778503417969 accuracy=60.15603232098078
# learning_rate=0.01
# epoch=84 total_train_loss=1.0110527276992798 accuracy=61.7088717823679
# epoch=84 total_validation_loss=1.0412026643753052 accuracy=60.89439955419337
# learning_rate=0.01
# epoch=85 total_train_loss=1.015743613243103 accuracy=61.61830784771326
# epoch=85 total_validation_loss=1.059874415397644 accuracy=59.93312900529396
# learning_rate=0.009000000000000001
# epoch=86 total_train_loss=0.9994590878486633 accuracy=62.454282629140685
# epoch=86 total_validation_loss=1.054022192955017 accuracy=60.51825020897186
# learning_rate=0.009000000000000001
# epoch=87 total_train_loss=0.9943681955337524 accuracy=62.56574593333101
# epoch=87 total_validation_loss=1.0723602771759033 accuracy=59.73808860406798
# learning_rate=0.009000000000000001
# epoch=88 total_train_loss=1.0003191232681274 accuracy=62.137308857849455
# epoch=88 total_validation_loss=1.0408086776733398 accuracy=60.15603232098078
# learning_rate=0.009000000000000001
# epoch=89 total_train_loss=1.0019181966781616 accuracy=62.210456651224355
# epoch=89 total_validation_loss=1.0507516860961914 accuracy=60.54611312343271
# learning_rate=0.009000000000000001
# epoch=90 total_train_loss=0.9937254190444946 accuracy=62.67720923752133
# epoch=90 total_validation_loss=1.0717673301696777 accuracy=59.668431317915854
# learning_rate=0.008100000000000001
# epoch=91 total_train_loss=0.9904930591583252 accuracy=62.55877947681912
# epoch=91 total_validation_loss=1.0623687505722046 accuracy=60.25355252159376
# learning_rate=0.008100000000000001
# epoch=92 total_train_loss=0.99298095703125 accuracy=62.72249120484865
# epoch=92 total_validation_loss=1.0593830347061157 accuracy=60.114237949289496
# learning_rate=0.008100000000000001
# epoch=93 total_train_loss=0.9921087622642517 accuracy=62.60406144414643
# epoch=93 total_validation_loss=1.0465977191925049 accuracy=60.922262468654225
# learning_rate=0.008100000000000001
# epoch=94 total_train_loss=0.9895350933074951 accuracy=62.68765892228918
# epoch=94 total_validation_loss=1.0709666013717651 accuracy=60.22568960713291
# learning_rate=0.008100000000000001
# epoch=95 total_train_loss=0.9866377711296082 accuracy=62.94890104148525
# epoch=95 total_validation_loss=1.0939818620681763 accuracy=59.1111730286988
# learning_rate=0.007290000000000001
# epoch=96 total_train_loss=0.9836143255233765 accuracy=62.997666237068515
# saving model...
# epoch=96 total_validation_loss=1.0237213373184204 accuracy=61.53524658679298
# learning_rate=0.007290000000000001
# epoch=97 total_train_loss=0.9809815883636475 accuracy=62.93148490020551
# epoch=97 total_validation_loss=1.0367306470870972 accuracy=61.24268598495403
# learning_rate=0.007290000000000001
# epoch=98 total_train_loss=0.9749383926391602 accuracy=63.29722386708001
# epoch=98 total_validation_loss=1.05074143409729 accuracy=60.50431875174143
# learning_rate=0.007290000000000001
# epoch=99 total_train_loss=0.9862638115882874 accuracy=62.806088682991394
# epoch=99 total_validation_loss=1.0353580713272095 accuracy=61.53524658679298
# learning_rate=0.007290000000000001
# epoch=100 total_train_loss=0.974173903465271 accuracy=63.52711693197255
# epoch=100 total_validation_loss=1.0291309356689453 accuracy=61.11730286988019
# learning_rate=0.006561
# epoch=101 total_train_loss=0.969886302947998 accuracy=63.39475425824654
# saving model...
# epoch=101 total_validation_loss=1.0056556463241577 accuracy=62.426859849540264
# learning_rate=0.006561
# epoch=102 total_train_loss=0.96927809715271 accuracy=63.37385488871086
# epoch=102 total_validation_loss=1.011484980583191 accuracy=62.17609361939259
# learning_rate=0.006561
# epoch=103 total_train_loss=0.9667769074440002 accuracy=63.642063464418825
# epoch=103 total_validation_loss=1.044264554977417 accuracy=60.991919754806354
# learning_rate=0.006561
# epoch=104 total_train_loss=0.970980167388916 accuracy=63.24845867149674
# epoch=104 total_validation_loss=1.042194128036499 accuracy=61.17302869880189
# learning_rate=0.006561
# epoch=105 total_train_loss=0.9691522717475891 accuracy=63.551499529764186
# epoch=105 total_validation_loss=1.0432500839233398 accuracy=60.85260518250209
# learning_rate=0.005904900000000001
# epoch=106 total_train_loss=0.9565975666046143 accuracy=63.91375526838274
# epoch=106 total_validation_loss=1.060227632522583 accuracy=60.01671774867651
# learning_rate=0.005904900000000001
# epoch=107 total_train_loss=0.9524175524711609 accuracy=64.15061478978717
# epoch=107 total_validation_loss=1.0252195596694946 accuracy=61.70242407355809
# learning_rate=0.005904900000000001
# epoch=108 total_train_loss=0.9550445675849915 accuracy=64.2551116374656
# epoch=108 total_validation_loss=1.0438084602355957 accuracy=61.047645583728055
# learning_rate=0.005904900000000001
# epoch=109 total_train_loss=0.9626126289367676 accuracy=64.07050053990038
# epoch=109 total_validation_loss=1.0390490293502808 accuracy=60.67149623850655
# learning_rate=0.005904900000000001
# epoch=110 total_train_loss=0.9565325975418091 accuracy=63.9694869204779
# epoch=110 total_validation_loss=1.009921669960022 accuracy=61.911395932014486
# learning_rate=0.00531441
# epoch=111 total_train_loss=0.9469455480575562 accuracy=64.33174265909645
# epoch=111 total_validation_loss=1.0226449966430664 accuracy=62.23181944831429
# learning_rate=0.00531441
# epoch=112 total_train_loss=0.9446271061897278 accuracy=64.72883068027448
# epoch=112 total_validation_loss=1.0411567687988281 accuracy=61.03371412649763
# learning_rate=0.00531441
# epoch=113 total_train_loss=0.9499799013137817 accuracy=64.06005085513253
# epoch=113 total_validation_loss=1.0137500762939453 accuracy=62.20395653385344
# learning_rate=0.00531441
# epoch=114 total_train_loss=0.9441083073616028 accuracy=64.38399108293567
# saving model...
# epoch=114 total_validation_loss=1.0051366090774536 accuracy=61.86960156032321
# learning_rate=0.00531441
# epoch=115 total_train_loss=0.9475247263908386 accuracy=64.79152878888154
# epoch=115 total_validation_loss=1.008987307548523 accuracy=62.23181944831429
# learning_rate=0.004782969000000001
# epoch=116 total_train_loss=0.940161943435669 accuracy=64.66264934341147
# epoch=116 total_validation_loss=1.030510663986206 accuracy=61.799944274171075
# learning_rate=0.004782969000000001
# epoch=117 total_train_loss=0.9397292137145996 accuracy=64.6138841478282
# epoch=117 total_validation_loss=1.051588535308838 accuracy=60.05851212036779
# learning_rate=0.004782969000000001
# epoch=118 total_train_loss=0.9374778866767883 accuracy=64.97613988644676
# epoch=118 total_validation_loss=1.06638765335083 accuracy=60.03064920590694
# learning_rate=0.004782969000000001
# epoch=119 total_train_loss=0.940834641456604 accuracy=64.82287784318507
# epoch=119 total_validation_loss=1.0131596326828003 accuracy=62.190025076623016
# learning_rate=0.004782969000000001
# epoch=120 total_train_loss=0.943361759185791 accuracy=64.3352258873524
# epoch=120 total_validation_loss=1.0216015577316284 accuracy=61.59097241571468
# learning_rate=0.004304672100000001
# epoch=121 total_train_loss=0.9307981133460999 accuracy=65.00748894075029
# epoch=121 total_validation_loss=1.016515851020813 accuracy=62.05071050431875
# learning_rate=0.004304672100000001
# epoch=122 total_train_loss=0.9324138760566711 accuracy=65.08063673412519
# saving model...
# epoch=122 total_validation_loss=0.9923439025878906 accuracy=62.59403733630538
# learning_rate=0.004304672100000001
# epoch=123 total_train_loss=0.9274096488952637 accuracy=65.00052248423839
# saving model...
# epoch=123 total_validation_loss=0.9906771779060364 accuracy=62.44079130677069
# learning_rate=0.004304672100000001
# epoch=124 total_train_loss=0.9319307804107666 accuracy=65.02490508203003
# epoch=124 total_validation_loss=1.0258052349090576 accuracy=61.66062970186682
# learning_rate=0.004304672100000001
# epoch=125 total_train_loss=0.9332621097564697 accuracy=64.79501201713748
# epoch=125 total_validation_loss=1.0276374816894531 accuracy=61.63276678740596
# learning_rate=0.003874204890000001
# epoch=126 total_train_loss=0.9221236109733582 accuracy=65.18513358180361
# epoch=126 total_validation_loss=1.0122624635696411 accuracy=61.7581499024798
# learning_rate=0.003874204890000001
